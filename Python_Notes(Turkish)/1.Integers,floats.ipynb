# %% [markdown]
# # INTEGERS AND FLOATS
# Integers tam sayı tipinden veri tutar.
# FLoat ondalıklı sayı tiğinden veri tutar.

# %%
type(3)
# Out:
# int

# %%
type(4.2)
# Out:
# float

# %% [markdown]
# "+" toplama<br/>
# "-" çıkarma<br/>
# / bölme<br/>
# "*" çarpma<br/>
# "//" tam sayı bölme<br/>
# "%" kalan mod <br/>
# "**" üs veya karekök alma<br/>

# %%
4+3
# Out:
# 7

# %%
4-3
# Out:
# 1

# %%
4/3
# Out:
# 1.3333333333333333

# %%
4*3
# Out:
# 12

# %%
4//3
# Out:
# 1

# %%
4%3
# Out:
# 1

# %%
4**3
# Out:
# 64

# %%
4**0.5
# Out:
# 2.0

# %% [markdown]
# int() -- içine verilen değeri integera çevirir <br/>
# float() -- içine verilen değeri floata çevirir<br/>
# eğer karakter alırlarsa hata döndürürler

# %%
int(4.5)
# Out:
# 4

# %%
float(3)
# Out:
# 3.0

# %%
# Yorum satırı bu işaretin sağında ki kodlar yorum olarak algılanır

# %% [markdown]
# Değişken tanımlama belirtilen değişkene veri tiğini ve veriyi kaydetmeyi sağlar

# %%
değişken=1
print(değişken)
# Out:
# 1
